# %% [markdown]
# # Automatic Salt Body Interpretation with CNN
#
# Author: Yu Zeng  Date: Feb. 07, 2019
#
# This notebook contains sample codes to train convolutional neural networks for our paper **Automatic Seismic Salt Interpretation with Deep Convolutional Neural Networks** ([arxiv:1802.01101](https://arxiv.org/abs/1812.01101)) (co-authors: Kebei Jiang and Jie Chen). This paper has been accepted by *The 3rd International Conference on Information System and Data Mining* ([ICISDM 2019](http://icisdm.org/)).
#
# For demonstration purpose only, I trained 40 epochs in this notebook to show the basic our working flow and basic ideas.
#
# Key steps for this Machine Learning project:
# -  [1. Introduction](#cell_0)
#
#
# -  [2. Input data preparation](./salt_body_segyin_data_prep.ipynb) (discussed in a separate notebook)
#     * 2.1 SEGY file read-in
#     * 2.2 Raw data QC and data transformation
#     * 2.3 Data cropping into small pieces (101x101)
#     * 2.4 Save cropped pieces as inputs for CNN test
#     * 2.5 Read-back QC
#
#
# -  [3. Data Loading and QC](#cell_2)
#     * [3.1 Load training data from earlier preparation](#cell_2_1)
#     * [3.2 Classify salt mask types based on coverage](#cell_2_2)
#
#
# -  [4. Network](#cell_3)
#     * [4.1 Network architecture](#cell_3_1)
#     * [4.2 Evaluate metrics](#cell_3_2)
#     * [4.3 Network training considerations: stratified K-fold](#cell_3_3)
#     * [4.4 Construction of U-Net + ResNet Networks](#cell_3_4)
#     * [4.5 Lovasz hinge Jaccard loss](#cell_3_5)
#
#
# -  [5. Network Training](#cell_4)
#     * [5.1 Learning rate scheduling](#cell_4_1)
#     * [5.2 First round of training:](#cell_4_2) $\eta_1=0.001$ with Cross Entropy as loss (20 epoch)
#     * [5.3 Second round of training:](#cell_4_3) $\eta_2=0.0005$ with Lovasz hinge as loss (10 epoch)
#     * [5.4 Third round of training:](#cell_4_4) $\eta_3=0.0001$ with Lavasz hinge as loss (10 epoch)
#
#
# -  [6. Result](#cell_5)
#     * [6.1 Load test seismic images](#cell_5_1)
#     * [6.2 Save prediction results as numpy array](#cell_5_2)
#     * [6.3 Read back predictions and combine](#cell_5_3)
#     * [6.4 Overlay with block information and compare with true labels](#cell_5_4)
#
#
# -  [7. Discussion](#cell_6)
#
#
# -  [8. Conclusion](#cell_7)
#
#
# -  [9. Appendix](#cell_8)
#     * [A. Model summary](#cell_8a)
#     * [B. ELU vs. ReLU](#cell_8b)
#
#
# -  [10. References](#cell_9)

# %% [markdown]
# ## 1. Introduction <a id='cell_0'></a>

# %% [markdown]
# One of the most crucial tasks in seismic reflection imaging is to identify the salt bodies with high precision. Traditionally, this is accomplished by visually picking the salt/sediment boundaries, which requires a great amount of manual work and may introduce systematic bias. With recent progress of deep learning algorithm and growing computational power, a great deal of efforts have been made to replace human effort with machine power in salt body interpretation.
#
# Currently, the method of Convolutional neural networks (CNN) is revolutionizing the computer vision field and has been a hot topic in the image analysis. In this Machine Learning project, the benefits of CNN-based classification are demonstrated by using a state-of-art network structure U-Net, along with the residual learning framework ResNet, to delineate salt body with high precision. Network adjustments, including the Exponential Linear Units (ELU) activation function, the Lovász-Softmax loss function, and stratified K-fold cross-validation, have been deployed to further improve the prediction accuracy.
#
# The preliminary result using SEG Advanced Modeling (SEAM) data shows good agreement between the predicted salt body and manually interpreted salt body, especially in areas with weak reflections. This indicates the great potential of applying CNN for salt-related interpretations.

# %% [markdown]
# First, let's import a few common modules

# %%
import os
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

import cv2
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

# import keras modules to construct network architecture
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img,save_img

import time
t_start = time.time()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# Details for data preparation is summarized in a [different notebook](./salt_body_segyin_data_prep.ipynb).

# %% [markdown]
# ## 3. Data Loading and QC <a id='cell_2'></a>

# %% [markdown]
# ### 3.1 Load training data from earlier preparation <a id="cell_2_1"></a>

# %%
# Loading of training/testing ids
train_df = pd.read_excel("C:/Users/idrun/Documents/01_DataScience/03_Salt_paper/03_png/train_1113a.xlsx", index_col='id')
len(train_df)
# Loading seismic images & corresponding interpreted labels/masks
train_df["images"] = [np.array(load_img("C:/Users/idrun/Documents/01_DataScience/03_Salt_paper/03_png/tmp_new_1113/images/train/image_{}.png".format(idx), color_mode="grayscale")) / 255 for idx in tqdm_notebook(train_df.index)]
train_df["masks"] = [np.array(load_img("C:/Users/idrun/Documents/01_DataScience/03_Salt_paper/03_png/tmp_new_1113/labels/train/label_{}.png".format(idx), color_mode="grayscale")) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=616), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=616), HTML(value='')))

# %% [markdown]
# ### 3.2 Classify salt mask types based on coverage <a id="cell_2_2"></a>

# %%
# define upsample in case needed
def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)

# define downsample in case needed
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# categorize salt mask type depending on salt coverage within the image 
def get_mask_type(mask):
    border = 10
    outer = np.zeros((101-2*border, 101-2*border), np.float32)
    outer = cv2.copyMakeBorder(outer, border, border, border, border, borderType = cv2.BORDER_CONSTANT, value = 1)

    cover = (mask>0.5).sum()
    if cover < 8:
        return 0 # empty
    if cover == ((mask*outer) > 0.5).sum():
        return 1 #border
    if np.all(mask==mask[0]):
        return 2 #vertical

    percentage = cover/(101*101)
    if percentage < 0.15:
        return 3
    elif percentage < 0.25:
        return 4
    elif percentage < 0.50:
        return 5
    elif percentage < 0.75:
        return 6
    else:
        return 7

# calcuate histogram coverage
def histcoverage(coverage):
    histall = np.zeros((1,8))
    for c in coverage:
        histall[0,c] += 1
    return histall

# %% [markdown]
# Create coverage class for later stratified sampling:

# %%
# inputs are already in 101x101, no need further up-sampling or down-sampling
img_size_ori = 101
img_size_target = 101

# create additional column based on salt coverge
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_target, 2)
train_df["coverage_class"] = train_df.masks.map(get_mask_type)

# %% [markdown]
# ## 4. Networks <a id='cell_3'></a>

# %% [markdown]
# ### 4.1 Network architecture <a id="cell_3_1"></a>

# %% [markdown]
# The U-Net structure, which combines a contracting/down-sampling path to extract context information and a symmetric expanding/up-sampling path to retrieve location information, has been used as our baseline architecture. To overcome the degradation problem with deep learning networks, a particular variant of U-Net is adopted in our experiments: the Deep Residual Learning or the ResNet.
#
# ResNet is constructed by adding an identity mapping shortcut on top of every few stacked layers. This will result in higher prediction precision due to the fact that it is easier to learn the mapping of the residual, which is close to zero, than to directly learn from the full input.
#
# A schematic view of network architecture used in our experiment is shown below:
#
# <img src="Unet.png">

# %% [markdown]
# ### 4.2 Evaluation Metric <a id="cell_3_2"></a>

# %% [markdown]
# In our experimentation, the intersection-over-union (IoU) score, also known as Jaccard index, is used to quantify the performance of CNN salt prediction. IoU socre is the more widely accepted evaluation metric in the image segmentation.
# IoU measures the similarity between two or more definitive sample sets. Mathematically, it can be written as the intersection divied by the union of the sample sets:
# <h1>
# <center>
# $J(A,B) = \frac{A\cap B}{ A\cup B}$
# </center>
# </h1>
# This will generate a statistic between 0 and 1. Higher IoU score means better consistence between the predicted salt pixels and the ground truth sal mask.

# %%
# calculate IoU between A & B
def get_iou_vector(A, B):
    A = np.squeeze(A) # new added 
    B = np.squeeze(B) # new added
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
        if np.count_nonzero(t) == 0 and np.count_nonzero(p) > 0:
            metric.append(0)
            continue
        if np.count_nonzero(t) >= 1 and np.count_nonzero(p) == 0:
            metric.append(0)
            continue
        if np.count_nonzero(t) == 0 and np.count_nonzero(p) == 0:
            metric.append(1)
            continue
        
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0)  )/ (np.sum(union > 0) )
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

# use IoU as metric, for cross entropy, threshold=0.5
def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

# use IoU as metric, for Lovasz, change threshold to 0
def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %% [markdown]
# ### 4.3 Network Training Considerations: Stratified K-fold <a id="cell_3_3"></a>

# %% [markdown]
# For neural networks, differences in random initialization, random mini-batch selection, and differences in hyperparameter space will tend to make prediction errors from different folds to be partially independent. The ensemble of the K models will, on average, perform better than its member models if the errors are not perfectly correlated. Below is a brief theoretical proof.
#
# The exepcted variance of ensemble model will be:
#
# $\mathbb{E}\left[\frac{1}{K}\left( \sum_{i} \delta_i  \right)^2\right] =
#     \frac{1}{K^2} \mathbb{E} \left[ \sum_{i} \left( \delta_i^2 + \sum_{j\ne i}\delta_i\delta_j \right) \right] = \frac{Var}{K} + \frac{(K-1)\cdot COV}{K}$
#
# In the case where errors are independent, convariance $COV$ will be 0 and the above equation can be simplified as:
#
# $\mathbb{E}\left[\frac{1}{K}\left( \sum_{i} \delta_i  \right)^2\right] = \frac{Var}{K}$
#
# If however, the errors are perfectly correlated, variance and covariance will be identical and the equation will be simplied as:
#
# $\mathbb{E}\left[\frac{1}{K}\left( \sum_{i} \delta_i  \right)^2\right] = Var$
#
# If errors are partially correlated, the expected variance of ensemble model will be within the two extreme values:
#
# $\frac{Var}{K} < E\left[\frac{1}{K}\left( \sum_i \delta_i  \right)^2\right] < Var $
#
#
# Let's create stratified K-fold. During training, we will train on K-1 folds and make predictions and evaluations on the remaining 1 fold. The stratified K-fold sampling is performed to produce folds that contain a representative ratio of each class and is thus a better way to split training data. For this test, I will use K=5.

# %%
cv_total = 5   # 5-fold

train_all = []
evaluate_all = []
skf = StratifiedKFold(n_splits=cv_total, random_state=1234, shuffle=False) # set fixed random_state to get identical result
for train_index, evaluate_index in skf.split(train_df.index.values, train_df.coverage_class):
    train_all.append(train_index)
    evaluate_all.append(evaluate_index)
    print(train_index.shape,evaluate_index.shape) # the shape is slightly different in different cv, it's OK
# Out:
# C:\Users\idrun\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 4 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# (490,) (126,)
# (491,) (125,)
# (493,) (123,)
# (494,) (122,)
# (496,) (120,)

# %% [markdown]
# Show some examples with different salt mask types, depending on coverage.

# %%
cv_index = 1   # check cv 1
train_index = train_all[cv_index-1]
evaluate_index = evaluate_all[cv_index-1]
print(train_index.shape,evaluate_index.shape)

histall = histcoverage(train_df.coverage_class[train_index].values)
print(f'train cv{cv_index}, number of each mask class = \n \t{histall}')

print('histall: ', histall.shape)
histall_test = histcoverage(train_df.coverage_class[evaluate_index].values)
print(f'evaluate cv{cv_index}, number of each mask class = \n \t {histall_test}')

n_qc_rows=2
n_qc_cols=histall.shape[1]
fig, axes = plt.subplots(nrows=n_qc_rows, ncols=n_qc_cols, figsize=(24, 6), sharex=True, sharey=True)

# show mask class example
for c in range(n_qc_cols):
    j= 0
    for i in train_index:
        if train_df.coverage_class[i] == c:
            axes[j,c].imshow(np.array(train_df.masks[i])  )
            axes[j,c].set_axis_off()
            axes[j,c].set_title(f'class {c}')
            j += 1
            if(j>=2):
                break
# Out:
# (490,) (126,)
# train cv1, number of each mask class =
#  	[[ 97.  19. 316.   8.   3.   9.  16.  22.]]
# histall:  (1, 8)
# evaluate cv1, number of each mask class =
#  	 [[25.  5. 79.  3.  1.  3.  4.  6.]]

# %% [markdown]
# ### 4.4 Construction of U-Net + ResNet Networks <a id="cell_3_4"></a>

# %% [markdown]
# Let's first build the residual block (ResNet) component. This ResNet component will be used as a building block when creating the U-Net architecture in a bigger scale.

# %%
# batch norm + activation with ReLU
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)  # activation uses ReLU as default
    return x

# use stride=1 and same padding for convolution block,
# by default (activation=True), it will perform conv2d plus BatchNorm and Activation with ReLU
# if activation=False, it will only perform conv2d
def convolution_block(x, filters, kernal_size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, kernal_size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
    return x

# -----------------------------------------
# construct structures for Residual Block
def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) ) # kernal size=(3,3), with activation=True by default
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %% [markdown]
# Now, let's start building an U-Net structure. Within each U-net layer, two residual blocks are used. A long the U-Net path, the input dimension changes from:
#
# [101x101x1] --> [101x101x16] --> [50x50x32] --> [25x25x64] --> [12x12x128] --> [6x6x256] --> [12x12x128] --> [25x25x64] --> [50x50x32] --> [101x101x32] --> [101x101x1].
#
# The information from layers in contracting path is transferred to the corresonding layer in the expanding path.

# %%
# ---------------------------------------------------------------------------
# Construct U-net architecture, given_input layer, then return output_layer
def build_model(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    # concatenate deconv4 & conv4 to transfer information from contracting path to expansive path
    uconv4 = concatenate([deconv4, conv4])   
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# -------------------------------
# build a full model using Keras
def build_compile_model(lr = 0.01):
    input_layer = Input((img_size_target, img_size_target, 1))   # input is 101x101x1
    output_layer = build_model(input_layer, 16,0.5)  # U-net structure, start with 16 neurons, dropout=0.5

    # build model using Keras Model class API with input_layer & output_layer
    model1 = Model(inputs=input_layer, outputs=output_layer)
    c = optimizers.adam(lr = lr)
    model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])
    return model1

# %% [markdown]
# Add a few necessary functions: plot function to QC training progress and predict function to get prediction results.

# %%
# ------------------------------------------------------
# define plotting tools
def plot_history(history,metric_name):
    fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_score.plot(history.epoch, history.history[metric_name], label="Train score")
    ax_score.plot(history.epoch, history.history["val_" + metric_name], label="Validation score")
    ax_score.legend()

# ------------------------------------------------------------------
# prediction result: Note only left/right flip is implemented here. 
# Other augmentation can be added when needed
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %% [markdown]
# ### 4.5 Lovasz hinge Jaccard loss function <a id="cell_3_5"></a>

# %% [markdown]
# According to some literature, better results might be achieved by optimizing with cross-entropy first, then fine-tune with Lovas hing loss. We are going to adopt this approach to further improve our model.
#
# Below are the implemention of Lavasz hinge Jaccard loss I found from [GitHub resources](https://github.com/bermanmaxim/LovaszSoftmax). These codes are borrowed for the salt body prediction test.

# %%
# Lovasz-Softmax and Jaccard hinge loss in Tensorflow
# Maxim Berman 2018 ESAT-PSI KU Leuven (MIT License)
#
# code borrowed from: https://github.com/bermanmaxim/LovaszSoftmax

def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard

# --------------------------- BINARY LOSSES ---------------------------
def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss

# can switch from relu to elu to improve prediction (Yu)
def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """
    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)  # original value 0, 1
        signs = 2. * labelsf - 1.                # new value in -1, 1
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        # Below use relu (default)
        #loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        # Below use elu (new), switch to elu to improve
        loss = tf.tensordot(tf.nn.elu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")

        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss

def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

# --------------------------- END BORROWING ---------------------------

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred     # if set logits to y_pred here, we'll need to change my_iou_metric_2 threshold to 0.0
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %% [markdown]
# ## 5. Network Training  <a id='cell_4'></a>

# %% [markdown]
# First, let's define a common function used for train & validation split:

# %%
# get train / valid split
def get_cv_data(cv_index):
    """ cv_index is >=1 """
    train_index = train_all[cv_index-1]
    evaluate_index = evaluate_all[cv_index-1]
    # reshape to tensor [None, 101, 101, 1]
    x_train = np.array(train_df.images[train_index].map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1)
    y_train = np.array(train_df.masks[train_index].map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1)
    x_valid = np.array(train_df.images[evaluate_index].map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1)
    y_valid = np.array(train_df.masks[evaluate_index].map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1)
    return x_train, y_train, x_valid, y_valid

# %% [markdown]
# Let's also define CV value and model names:

# %%
# define 5 fold
cv_total=5  

# define model names
date = '0207'
version = '01a'
basic_name = f'Unet_resnet_{date}_v{version}'
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# Unet_resnet_0207_v01a.model
# Unet_resnet_0207_v01a.csv

# %% [markdown]
# ### 5.1 Learning rate scheduling <a id="cell_4_1"></a>

# %% [markdown]
# The ideal learning rate has the advantage of learning quikly and converge to optimal solution. However, finding a good learning rate can be tricky. In this salt body interpretation experiment, we adopted a simple strategy called ***predetermined piecewise constant learning rate***.
#
# The initial learning rate is set to $\eta_1 = 0.001$, then $\eta_2 = 0.0005$ and finally $\eta_3=0.0001$ for various training epochs. This strategy, though not optimal, turns out to work reasonably well. To further improve, a method with cyclic learning rate can be implemented.

# %% [markdown]
# ### 5.2 First round of training: $\eta_1=0.001$ with Cross Entropy as loss <a id="cell_4_2"></a>

# %% [markdown]
# First pass of training with $\eta_1=0.001$. I use 20 epochs here for demonstration purpose, without using early stopping etc. In this first pass of training, cross-entropy loss is used for optimization. Standard Adam optimizer is used.

# %%
# List to store IoU scores for each CV.
ious = [0] * cv_total

epochs = 20  # small number for demonstration
batch_size = 32
learning_rate = 0.001


for cv_index in range(cv_total):
    # set model names for each CV
    basic_name = f'Unet_resnet_{date}_v{version}_cv{cv_index+1}'
    print('############################################\n', basic_name)
    save_model_name = basic_name + '.model'
    
    # train, valid split
    x_train, y_train, x_valid, y_valid =  get_cv_data(cv_index+1)
    
    # Data augmentation (horizontal flip only)
    x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
    y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)

    # construct full model
    model = build_compile_model(lr = learning_rate)

    # model ckpt, save model with name "save_model_name"
    model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
    
    # reduce_lr for future usage
    reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode = 'max',
                                  factor=0.5, patience=3, min_lr=0.0001, verbose=0)
    
    #list_callbacks = [model_checkpoint, reduce_lr]
    list_callbacks = [model_checkpoint]
    
    # plot fit history
    history = model.fit(x_train, y_train,
                        validation_data=[x_valid, y_valid], 
                        epochs=epochs,
                        batch_size=batch_size,
                        #callbacks=[ model_checkpoint,reduce_lr], 
                        callbacks = list_callbacks,
                        shuffle=False,
                        verbose=2)
    plot_history(history,'my_iou_metric')
    
    # load model
    model.load_weights(save_model_name)
    # predict  
    preds_valid = predict_result(model,x_valid,img_size_target)
    # obtain IoU score
    ious[cv_index] = get_iou_vector(y_valid, (preds_valid > 0.5))

# get model summary
model.summary()
# Out:
# ############################################
#  Unet_resnet_0207_v01a_cv1
# Train on 980 samples, validate on 126 samples
# Epoch 1/20
#  - 16s - loss: 0.5693 - my_iou_metric: 0.5600 - val_loss: 7.7723 - val_my_iou_metric: 0.0508
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.05079, saving model to Unet_resnet_0207_v01a_cv1.model
# Epoch 2/20
#  - 5s - loss: 0.5059 - my_iou_metric: 0.5596 - val_loss: 3.6981 - val_my_iou_metric: 0.0714
#
# Epoch 00002: val_my_iou_metric improved from 0.05079 to 0.07143, saving model to Unet_resnet_0207_v01a_cv1.model
# Epoch 3/20
#  - 5s - loss: 0.4662 - my_iou_metric: 0.5400 - val_loss: 6.5449 - val_my_iou_metric: 0.0079
#
# Epoch 00003: val_my_iou_metric did not improve from 0.07143
# Epoch 4/20
#  - 5s - loss: 0.4029 - my_iou_metric: 0.5808 - val_loss: 5.6185 - val_my_iou_metric: 0.3921
#
# Epoch 00004: val_my_iou_metric improved from 0.07143 to 0.39206, saving model to Unet_resnet_0207_v01a_cv1.model
# Epoch 5/20
#  - 5s - loss: 0.5460 - my_iou_metric: 0.6362 - val_loss: 4.7498 - val_my_iou_metric: 0.6778
#
# Epoch 00005: val_my_iou_metric improved from 0.39206 to 0.67778, saving model to Unet_resnet_0207_v01a_cv1.model
# Epoch 6/20
#  - 5s - loss: 0.4818 - my_iou_metric: 0.6592 - val_loss: 3.7076 - val_my_iou_metric: 0.0079
#
# Epoch 00006: val_my_iou_metric did not improve from 0.67778
# Epoch 7/20
#  - 5s - loss: 0.3839 - my_iou_metric: 0.5838 - val_loss: 5.1041 - val_my_iou_metric: 0.0159
#
# Epoch 00007: val_my_iou_metric did not improve from 0.67778
# Epoch 8/20
#  - 5s - loss: 0.3352 - my_iou_metric: 0.6164 - val_loss: 3.7096 - val_my_iou_metric: 0.3643
#
# Epoch 00008: val_my_iou_metric did not improve from 0.67778
# Epoch 9/20
#  - 5s - loss: 0.3217 - my_iou_metric: 0.6070 - val_loss: 3.8842 - val_my_iou_metric: 0.4000
#
# Epoch 00009: val_my_iou_metric did not improve from 0.67778
# Epoch 10/20
#  - 5s - loss: 0.3033 - my_iou_metric: 0.6201 - val_loss: 3.9338 - val_my_iou_metric: 0.3667
#
# Epoch 00010: val_my_iou_metric did not improve from 0.67778
# Epoch 11/20
#  - 5s - loss: 0.2698 - my_iou_metric: 0.6413 - val_loss: 1.6518 - val_my_iou_metric: 0.5222
#
# Epoch 00011: val_my_iou_metric did not improve from 0.67778
# Epoch 12/20
#  - 5s - loss: 0.2633 - my_iou_metric: 0.6437 - val_loss: 1.3399 - val_my_iou_metric: 0.5603
#
# Epoch 00012: val_my_iou_metric did not improve from 0.67778
# Epoch 13/20
#  - 5s - loss: 0.2448 - my_iou_metric: 0.6491 - val_loss: 1.3674 - val_my_iou_metric: 0.5111
#
# Epoch 00013: val_my_iou_metric did not improve from 0.67778
# Epoch 14/20
#  - 5s - loss: 0.2486 - my_iou_metric: 0.6477 - val_loss: 1.9407 - val_my_iou_metric: 0.5127
#
# Epoch 00014: val_my_iou_metric did not improve from 0.67778
# Epoch 15/20
#  - 5s - loss: 0.2272 - my_iou_metric: 0.6576 - val_loss: 1.3549 - val_my_iou_metric: 0.4341
#
# Epoch 00015: val_my_iou_metric did not improve from 0.67778
# Epoch 16/20
#  - 5s - loss: 0.2195 - my_iou_metric: 0.6672 - val_loss: 1.0145 - val_my_iou_metric: 0.6563
#
# Epoch 00016: val_my_iou_metric did not improve from 0.67778
# Epoch 17/20
#  - 5s - loss: 0.2024 - my_iou_metric: 0.6767 - val_loss: 1.0393 - val_my_iou_metric: 0.6675
#
# Epoch 00017: val_my_iou_metric did not improve from 0.67778
# Epoch 18/20
#  - 5s - loss: 0.1899 - my_iou_metric: 0.6947 - val_loss: 0.9074 - val_my_iou_metric: 0.6944
#
# Epoch 00018: val_my_iou_metric improved from 0.67778 to 0.69444, saving model to Unet_resnet_0207_v01a_cv1.model
# Epoch 19/20
#  - 5s - loss: 0.1862 - my_iou_metric: 0.6906 - val_loss: 0.9666 - val_my_iou_metric: 0.6881
#
# Epoch 00019: val_my_iou_metric did not improve from 0.69444
# Epoch 20/20
#  - 5s - loss: 0.1710 - my_iou_metric: 0.7182 - val_loss: 0.9521 - val_my_iou_metric: 0.6643
#
# Epoch 00020: val_my_iou_metric did not improve from 0.69444
# ############################################
#  Unet_resnet_0207_v01a_cv2
# Train on 982 samples, validate on 125 samples
# Epoch 1/20
#  - 15s - loss: 0.7351 - my_iou_metric: 0.1118 - val_loss: 0.7034 - val_my_iou_metric: 0.6088
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.60880, saving model to Unet_resnet_0207_v01a_cv2.model
# Epoch 2/20
#  - 5s - loss: 0.6532 - my_iou_metric: 0.5645 - val_loss: 0.7262 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00002: val_my_iou_metric did not improve from 0.60880
# Epoch 3/20
#  - 5s - loss: 0.5906 - my_iou_metric: 0.4529 - val_loss: 0.8594 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00003: val_my_iou_metric did not improve from 0.60880
# Epoch 4/20
#  - 5s - loss: 0.5410 - my_iou_metric: 0.4424 - val_loss: 11.3541 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00004: val_my_iou_metric did not improve from 0.60880
# Epoch 5/20
#  - 5s - loss: 0.4979 - my_iou_metric: 0.4820 - val_loss: 10.7851 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00005: val_my_iou_metric did not improve from 0.60880
# Epoch 6/20
#  - 5s - loss: 0.4776 - my_iou_metric: 0.5046 - val_loss: 10.3619 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00006: val_my_iou_metric did not improve from 0.60880
# Epoch 7/20
#  - 5s - loss: 0.4663 - my_iou_metric: 0.5398 - val_loss: 11.1112 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00007: val_my_iou_metric did not improve from 0.60880
# Epoch 8/20
#  - 6s - loss: 0.4737 - my_iou_metric: 0.5411 - val_loss: 11.2558 - val_my_iou_metric: 0.2000
#
# Epoch 00008: val_my_iou_metric did not improve from 0.60880
# Epoch 9/20
#  - 6s - loss: 0.4498 - my_iou_metric: 0.5617 - val_loss: 0.9757 - val_my_iou_metric: 0.6352
#
# Epoch 00009: val_my_iou_metric improved from 0.60880 to 0.63520, saving model to Unet_resnet_0207_v01a_cv2.model
# Epoch 10/20
#  - 6s - loss: 0.4161 - my_iou_metric: 0.5802 - val_loss: 10.2970 - val_my_iou_metric: 0.2000
#
# Epoch 00010: val_my_iou_metric did not improve from 0.63520
# Epoch 11/20
#  - 6s - loss: 0.3964 - my_iou_metric: 0.5957 - val_loss: 2.0775 - val_my_iou_metric: 0.4376
#
# Epoch 00011: val_my_iou_metric did not improve from 0.63520
# Epoch 12/20
#  - 5s - loss: 0.3811 - my_iou_metric: 0.6077 - val_loss: 0.8461 - val_my_iou_metric: 0.6360
#
# Epoch 00012: val_my_iou_metric improved from 0.63520 to 0.63600, saving model to Unet_resnet_0207_v01a_cv2.model
# Epoch 13/20
#  - 5s - loss: 0.3592 - my_iou_metric: 0.6350 - val_loss: 3.9417 - val_my_iou_metric: 0.0240
#
# Epoch 00013: val_my_iou_metric did not improve from 0.63600
# Epoch 14/20
#  - 5s - loss: 0.3589 - my_iou_metric: 0.6309 - val_loss: 7.9707 - val_my_iou_metric: 0.2000
#
# Epoch 00014: val_my_iou_metric did not improve from 0.63600
# Epoch 15/20
#  - 5s - loss: 0.3568 - my_iou_metric: 0.6271 - val_loss: 8.1984 - val_my_iou_metric: 0.2000
#
# Epoch 00015: val_my_iou_metric did not improve from 0.63600
# Epoch 16/20
#  - 5s - loss: 0.3407 - my_iou_metric: 0.6594 - val_loss: 0.8752 - val_my_iou_metric: 0.5384
#
# Epoch 00016: val_my_iou_metric did not improve from 0.63600
# Epoch 17/20
#  - 5s - loss: 0.3384 - my_iou_metric: 0.6823 - val_loss: 6.3801 - val_my_iou_metric: 0.2000
#
# Epoch 00017: val_my_iou_metric did not improve from 0.63600
# Epoch 18/20
#  - 5s - loss: 0.3840 - my_iou_metric: 0.6522 - val_loss: 5.1908 - val_my_iou_metric: 0.2000
#
# Epoch 00018: val_my_iou_metric did not improve from 0.63600
# Epoch 19/20
#  - 5s - loss: 0.3167 - my_iou_metric: 0.6804 - val_loss: 8.0506 - val_my_iou_metric: 0.2000
#
# Epoch 00019: val_my_iou_metric did not improve from 0.63600
# Epoch 20/20
#  - 6s - loss: 0.3017 - my_iou_metric: 0.7119 - val_loss: 1.8407 - val_my_iou_metric: 0.0024
#
# Epoch 00020: val_my_iou_metric did not improve from 0.63600
# ############################################
#  Unet_resnet_0207_v01a_cv3
# Train on 986 samples, validate on 123 samples
# Epoch 1/20
#  - 17s - loss: 0.6910 - my_iou_metric: 0.1135 - val_loss: 11.5646 - val_my_iou_metric: 0.1951
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.19512, saving model to Unet_resnet_0207_v01a_cv3.model
# Epoch 2/20
#  - 5s - loss: 0.5758 - my_iou_metric: 0.5501 - val_loss: 11.1912 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00002: val_my_iou_metric did not improve from 0.19512
# Epoch 3/20
#  - 5s - loss: 0.5243 - my_iou_metric: 0.6480 - val_loss: 9.3702 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00003: val_my_iou_metric did not improve from 0.19512
# Epoch 4/20
#  - 5s - loss: 0.4881 - my_iou_metric: 0.6232 - val_loss: 9.1379 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00004: val_my_iou_metric did not improve from 0.19512
# Epoch 5/20
#  - 5s - loss: 0.4563 - my_iou_metric: 0.6055 - val_loss: 11.4410 - val_my_iou_metric: 0.1951
# Epoch 00005: val_my_iou_metric did not improve from 0.19512
# Epoch 6/20
#  - 5s - loss: 0.4412 - my_iou_metric: 0.5954 - val_loss: 11.3720 - val_my_iou_metric: 0.1789
#
# Epoch 00006: val_my_iou_metric did not improve from 0.19512
# Epoch 7/20
#  - 5s - loss: 0.4064 - my_iou_metric: 0.6142 - val_loss: 11.2332 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00007: val_my_iou_metric did not improve from 0.19512
# Epoch 8/20
#  - 5s - loss: 0.4175 - my_iou_metric: 0.5813 - val_loss: 0.9753 - val_my_iou_metric: 0.6585
#
# Epoch 00008: val_my_iou_metric improved from 0.19512 to 0.65854, saving model to Unet_resnet_0207_v01a_cv3.model
# Epoch 9/20
#  - 5s - loss: 0.3256 - my_iou_metric: 0.6058 - val_loss: 0.8608 - val_my_iou_metric: 0.6683
#
# Epoch 00009: val_my_iou_metric improved from 0.65854 to 0.66829, saving model to Unet_resnet_0207_v01a_cv3.model
# Epoch 10/20
#  - 5s - loss: 0.2954 - my_iou_metric: 0.6301 - val_loss: 0.8490 - val_my_iou_metric: 0.6341
#
# Epoch 00010: val_my_iou_metric did not improve from 0.66829
# Epoch 11/20
#  - 5s - loss: 0.3357 - my_iou_metric: 0.6100 - val_loss: 1.3510 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00011: val_my_iou_metric did not improve from 0.66829
# Epoch 12/20
#  - 5s - loss: 0.2830 - my_iou_metric: 0.6344 - val_loss: 1.0628 - val_my_iou_metric: 0.6220
#
# Epoch 00012: val_my_iou_metric did not improve from 0.66829
# Epoch 13/20
#  - 5s - loss: 0.2647 - my_iou_metric: 0.6465 - val_loss: 1.6448 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00013: val_my_iou_metric did not improve from 0.66829
# Epoch 14/20
#  - 5s - loss: 0.2446 - my_iou_metric: 0.6531 - val_loss: 0.8700 - val_my_iou_metric: 0.6455
#
# Epoch 00014: val_my_iou_metric did not improve from 0.66829
# Epoch 15/20
#  - 5s - loss: 0.2294 - my_iou_metric: 0.6582 - val_loss: 0.9405 - val_my_iou_metric: 0.6341
#
# Epoch 00015: val_my_iou_metric did not improve from 0.66829
# Epoch 16/20
#  - 5s - loss: 0.2098 - my_iou_metric: 0.6650 - val_loss: 0.8913 - val_my_iou_metric: 0.6927
#
# Epoch 00016: val_my_iou_metric improved from 0.66829 to 0.69268, saving model to Unet_resnet_0207_v01a_cv3.model
# Epoch 17/20
#  - 6s - loss: 0.2270 - my_iou_metric: 0.6639 - val_loss: 0.9287 - val_my_iou_metric: 0.5886
#
# Epoch 00017: val_my_iou_metric did not improve from 0.69268
# Epoch 18/20
#  - 5s - loss: 0.1972 - my_iou_metric: 0.6742 - val_loss: 3.8137 - val_my_iou_metric: 0.0081
#
# Epoch 00018: val_my_iou_metric did not improve from 0.69268
# Epoch 19/20
#  - 5s - loss: 0.1846 - my_iou_metric: 0.7095 - val_loss: 4.0343 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00019: val_my_iou_metric did not improve from 0.69268
# Epoch 20/20
#  - 5s - loss: 0.1803 - my_iou_metric: 0.7150 - val_loss: 9.3461 - val_my_iou_metric: 0.1870
#
# Epoch 00020: val_my_iou_metric did not improve from 0.69268
# ############################################
#  Unet_resnet_0207_v01a_cv4
# Train on 988 samples, validate on 122 samples
# Epoch 1/20
#  - 17s - loss: 0.5906 - my_iou_metric: 0.6306 - val_loss: 10.2458 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.00000, saving model to Unet_resnet_0207_v01a_cv4.model
# Epoch 2/20
#  - 6s - loss: 0.5215 - my_iou_metric: 0.5566 - val_loss: 11.5137 - val_my_iou_metric: 0.1885
#
# Epoch 00002: val_my_iou_metric improved from 0.00000 to 0.18852, saving model to Unet_resnet_0207_v01a_cv4.model
# Epoch 3/20
#  - 6s - loss: 0.5049 - my_iou_metric: 0.5819 - val_loss: 1.6681 - val_my_iou_metric: 0.5090
#
# Epoch 00003: val_my_iou_metric improved from 0.18852 to 0.50902, saving model to Unet_resnet_0207_v01a_cv4.model
# Epoch 4/20
#  - 6s - loss: 0.4526 - my_iou_metric: 0.5823 - val_loss: 0.7623 - val_my_iou_metric: 0.4738
#
# Epoch 00004: val_my_iou_metric did not improve from 0.50902
# Epoch 5/20
#  - 5s - loss: 0.4497 - my_iou_metric: 0.5662 - val_loss: 11.6001 - val_my_iou_metric: 0.1967
#
# Epoch 00005: val_my_iou_metric did not improve from 0.50902
# Epoch 6/20
#  - 5s - loss: 0.4107 - my_iou_metric: 0.6247 - val_loss: 10.2714 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00006: val_my_iou_metric did not improve from 0.50902
# Epoch 7/20
#  - 5s - loss: 0.3579 - my_iou_metric: 0.6277 - val_loss: 1.5221 - val_my_iou_metric: 0.5615
#
# Epoch 00007: val_my_iou_metric improved from 0.50902 to 0.56148, saving model to Unet_resnet_0207_v01a_cv4.model
# Epoch 8/20
#  - 6s - loss: 0.3353 - my_iou_metric: 0.6315 - val_loss: 1.3294 - val_my_iou_metric: 0.7008
#
# Epoch 00008: val_my_iou_metric improved from 0.56148 to 0.70082, saving model to Unet_resnet_0207_v01a_cv4.model
# Epoch 9/20
#  - 6s - loss: 0.3449 - my_iou_metric: 0.6197 - val_loss: 1.8255 - val_my_iou_metric: 0.0877
#
# Epoch 00009: val_my_iou_metric did not improve from 0.70082
# Epoch 10/20
#  - 5s - loss: 0.3286 - my_iou_metric: 0.6173 - val_loss: 1.2412 - val_my_iou_metric: 0.6049
#
# Epoch 00010: val_my_iou_metric did not improve from 0.70082
# Epoch 11/20
#  - 5s - loss: 0.2862 - my_iou_metric: 0.6440 - val_loss: 1.3402 - val_my_iou_metric: 0.5672
#
# Epoch 00011: val_my_iou_metric did not improve from 0.70082
# Epoch 12/20
#  - 5s - loss: 0.2565 - my_iou_metric: 0.6568 - val_loss: 1.3184 - val_my_iou_metric: 0.4803
#
# Epoch 00012: val_my_iou_metric did not improve from 0.70082
# Epoch 13/20
#  - 6s - loss: 0.2302 - my_iou_metric: 0.6665 - val_loss: 1.3137 - val_my_iou_metric: 0.5779
#
# Epoch 00013: val_my_iou_metric did not improve from 0.70082
# Epoch 14/20
#  - 6s - loss: 0.2134 - my_iou_metric: 0.6728 - val_loss: 1.0110 - val_my_iou_metric: 0.6574
#
# Epoch 00014: val_my_iou_metric did not improve from 0.70082
# Epoch 15/20
#  - 6s - loss: 0.2201 - my_iou_metric: 0.6675 - val_loss: 1.2512 - val_my_iou_metric: 0.6434
#
# Epoch 00015: val_my_iou_metric did not improve from 0.70082
# Epoch 16/20
#  - 6s - loss: 0.1928 - my_iou_metric: 0.6787 - val_loss: 1.2771 - val_my_iou_metric: 0.5869
#
# Epoch 00016: val_my_iou_metric did not improve from 0.70082
# Epoch 17/20
#  - 6s - loss: 0.2519 - my_iou_metric: 0.6559 - val_loss: 1.6701 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00017: val_my_iou_metric did not improve from 0.70082
# Epoch 18/20
#  - 6s - loss: 0.2075 - my_iou_metric: 0.6655 - val_loss: 3.6454 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00018: val_my_iou_metric did not improve from 0.70082
# Epoch 19/20
#  - 6s - loss: 0.1708 - my_iou_metric: 0.6780 - val_loss: 0.5747 - val_my_iou_metric: 0.3623
#
# Epoch 00019: val_my_iou_metric did not improve from 0.70082
# Epoch 20/20
#  - 6s - loss: 0.1504 - my_iou_metric: 0.7100 - val_loss: 1.3073 - val_my_iou_metric: 0.6951
#
# Epoch 00020: val_my_iou_metric did not improve from 0.70082
# ############################################
#  Unet_resnet_0207_v01a_cv5
# Train on 992 samples, validate on 120 samples
# Epoch 1/20
#  - 19s - loss: 0.6373 - my_iou_metric: 0.4256 - val_loss: 11.2996 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.00000, saving model to Unet_resnet_0207_v01a_cv5.model
# Epoch 2/20
#  - 6s - loss: 0.5640 - my_iou_metric: 0.5633 - val_loss: 0.6151 - val_my_iou_metric: 0.7025
#
# Epoch 00002: val_my_iou_metric improved from 0.00000 to 0.70250, saving model to Unet_resnet_0207_v01a_cv5.model
# Epoch 3/20
#  - 6s - loss: 0.5352 - my_iou_metric: 0.5841 - val_loss: 9.9258 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00003: val_my_iou_metric did not improve from 0.70250
# Epoch 4/20
#  - 6s - loss: 0.5224 - my_iou_metric: 0.6198 - val_loss: 0.7632 - val_my_iou_metric: 0.4600
#
# Epoch 00004: val_my_iou_metric did not improve from 0.70250
# Epoch 5/20
#  - 6s - loss: 0.4324 - my_iou_metric: 0.5870 - val_loss: 1.9279 - val_my_iou_metric: 0.4258
#
# Epoch 00005: val_my_iou_metric did not improve from 0.70250
# Epoch 6/20
#  - 6s - loss: 0.3765 - my_iou_metric: 0.5913 - val_loss: 7.5412 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00006: val_my_iou_metric did not improve from 0.70250
# Epoch 7/20
#  - 6s - loss: 0.3411 - my_iou_metric: 0.6074 - val_loss: 2.6271 - val_my_iou_metric: 0.0050
#
# Epoch 00007: val_my_iou_metric did not improve from 0.70250
# Epoch 8/20
#  - 6s - loss: 0.3381 - my_iou_metric: 0.6212 - val_loss: 3.5822 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00008: val_my_iou_metric did not improve from 0.70250
# Epoch 9/20
#  - 6s - loss: 0.3145 - my_iou_metric: 0.6287 - val_loss: 0.9794 - val_my_iou_metric: 0.7042
#
# Epoch 00009: val_my_iou_metric improved from 0.70250 to 0.70417, saving model to Unet_resnet_0207_v01a_cv5.model
# Epoch 10/20
#  - 6s - loss: 0.2812 - my_iou_metric: 0.6474 - val_loss: 1.0940 - val_my_iou_metric: 0.7067
# Epoch 00010: val_my_iou_metric improved from 0.70417 to 0.70667, saving model to Unet_resnet_0207_v01a_cv5.model
# Epoch 11/20
#  - 6s - loss: 0.2768 - my_iou_metric: 0.6544 - val_loss: 1.3146 - val_my_iou_metric: 0.7083
#
# Epoch 00011: val_my_iou_metric improved from 0.70667 to 0.70833, saving model to Unet_resnet_0207_v01a_cv5.model
# Epoch 12/20
#  - 6s - loss: 0.2782 - my_iou_metric: 0.6539 - val_loss: 1.1946 - val_my_iou_metric: 0.7075
#
# Epoch 00012: val_my_iou_metric did not improve from 0.70833
# Epoch 13/20
#  - 6s - loss: 0.2579 - my_iou_metric: 0.6550 - val_loss: 1.4695 - val_my_iou_metric: 0.7025
#
# Epoch 00013: val_my_iou_metric did not improve from 0.70833
# Epoch 14/20
#  - 6s - loss: 0.2707 - my_iou_metric: 0.6346 - val_loss: 1.0666 - val_my_iou_metric: 0.5783
#
# Epoch 00014: val_my_iou_metric did not improve from 0.70833
# Epoch 15/20
#  - 6s - loss: 0.2435 - my_iou_metric: 0.6694 - val_loss: 1.5781 - val_my_iou_metric: 0.7058
#
# Epoch 00015: val_my_iou_metric did not improve from 0.70833
# Epoch 16/20
#  - 6s - loss: 0.2238 - my_iou_metric: 0.6644 - val_loss: 1.1842 - val_my_iou_metric: 0.7083
#
# Epoch 00016: val_my_iou_metric did not improve from 0.70833
# Epoch 17/20
#  - 6s - loss: 0.2138 - my_iou_metric: 0.6765 - val_loss: 1.3160 - val_my_iou_metric: 0.7083
#
# Epoch 00017: val_my_iou_metric did not improve from 0.70833
# Epoch 18/20
#  - 6s - loss: 0.1935 - my_iou_metric: 0.6834 - val_loss: 1.2692 - val_my_iou_metric: 0.7033
#
# Epoch 00018: val_my_iou_metric did not improve from 0.70833
# Epoch 19/20
#  - 6s - loss: 0.1862 - my_iou_metric: 0.6798 - val_loss: 1.0640 - val_my_iou_metric: 0.7083
#
# Epoch 00019: val_my_iou_metric did not improve from 0.70833
# Epoch 20/20
#  - 6s - loss: 0.1722 - my_iou_metric: 0.6840 - val_loss: 1.1165 - val_my_iou_metric: 0.7092
#
# Epoch 00020: val_my_iou_metric improved from 0.70833 to 0.70917, saving model to Unet_resnet_0207_v01a_cv5.model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 101, 101, 16) 160         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 101, 101, 16) 64          conv2d_185[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 101, 101, 16) 0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 101, 101, 16) 2320        activation_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 101, 101, 16) 64          conv2d_186[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 101, 101, 16) 0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 101, 101, 16) 2320        activation_186[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 101, 101, 16) 0           conv2d_187[0][0]
#                                                                  conv2d_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 101, 101, 16) 64          add_73[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 101, 101, 16) 0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 101, 101, 16) 2320        activation_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 101, 101, 16) 64          conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 101, 101, 16) 0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 101, 101, 16) 2320        activation_188[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 101, 101, 16) 0           conv2d_189[0][0]
#                                                                  add_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 101, 101, 16) 64          add_74[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 101, 101, 16) 0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 50, 50, 16)   0           activation_189[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 50, 50, 16)   0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 50, 50, 32)   4640        dropout_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 50, 50, 32)   128         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 50, 50, 32)   0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 50, 50, 32)   9248        activation_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 50, 50, 32)   128         conv2d_191[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 50, 50, 32)   0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 50, 50, 32)   9248        activation_191[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 50, 50, 32)   0           conv2d_192[0][0]
#                                                                  conv2d_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 50, 50, 32)   128         add_75[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 50, 50, 32)   0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 50, 50, 32)   9248        activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 50, 50, 32)   128         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 50, 50, 32)   0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 50, 50, 32)   9248        activation_193[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 50, 50, 32)   0           conv2d_194[0][0]
#                                                                  add_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 50, 50, 32)   128         add_76[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 50, 50, 32)   0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 25, 25, 32)   0           activation_194[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 25, 25, 32)   0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 25, 25, 64)   18496       dropout_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 25, 25, 64)   256         conv2d_195[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 25, 25, 64)   0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 25, 25, 64)   36928       activation_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 25, 25, 64)   256         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 25, 25, 64)   0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 25, 25, 64)   36928       activation_196[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 25, 25, 64)   0           conv2d_197[0][0]
#                                                                  conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 25, 25, 64)   256         add_77[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 25, 25, 64)   0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 25, 25, 64)   36928       activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 25, 25, 64)   256         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 25, 25, 64)   0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 25, 25, 64)   36928       activation_198[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 25, 25, 64)   0           conv2d_199[0][0]
#                                                                  add_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 25, 25, 64)   256         add_78[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 25, 25, 64)   0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 12, 12, 64)   0           activation_199[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 12, 12, 64)   0           max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 12, 12, 128)  73856       dropout_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 12, 12, 128)  512         conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 12, 12, 128)  0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 12, 12, 128)  147584      activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 12, 12, 128)  512         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 12, 12, 128)  0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 12, 12, 128)  147584      activation_201[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 12, 12, 128)  0           conv2d_202[0][0]
#                                                                  conv2d_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 12, 12, 128)  512         add_79[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 12, 12, 128)  0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 12, 12, 128)  147584      activation_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 12, 12, 128)  512         conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 12, 12, 128)  0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 12, 12, 128)  147584      activation_203[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 12, 12, 128)  0           conv2d_204[0][0]
#                                                                  add_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 12, 12, 128)  512         add_80[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 12, 12, 128)  0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 6, 6, 128)    0           activation_204[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 6, 6, 128)    0           max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 6, 6, 256)    295168      dropout_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 6, 6, 256)    1024        conv2d_205[0][0]
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, 6, 6, 256)    0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 6, 6, 256)    590080      activation_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 6, 6, 256)    1024        conv2d_206[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 6, 6, 256)    0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 6, 6, 256)    590080      activation_206[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 6, 6, 256)    0           conv2d_207[0][0]
#                                                                  conv2d_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 6, 6, 256)    1024        add_81[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 6, 6, 256)    0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 6, 6, 256)    590080      activation_207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 6, 6, 256)    1024        conv2d_208[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 6, 6, 256)    0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 6, 6, 256)    590080      activation_208[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 6, 6, 256)    0           conv2d_209[0][0]
#                                                                  add_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 6, 6, 256)    1024        add_82[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 6, 6, 256)    0           batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 12, 12, 128)  295040      activation_209[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 12, 12, 256)  0           conv2d_transpose_17[0][0]
#                                                                  activation_204[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 12, 12, 256)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 12, 12, 128)  295040      dropout_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 12, 12, 128)  512         conv2d_210[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 12, 12, 128)  0           batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 12, 12, 128)  147584      activation_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 12, 12, 128)  512         conv2d_211[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 12, 12, 128)  0           batch_normalization_207[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 12, 12, 128)  147584      activation_211[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 12, 12, 128)  0           conv2d_212[0][0]
#                                                                  conv2d_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 12, 12, 128)  512         add_83[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 12, 12, 128)  0           batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 12, 12, 128)  147584      activation_212[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 12, 12, 128)  512         conv2d_213[0][0]
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, 12, 12, 128)  0           batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 12, 12, 128)  147584      activation_213[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 12, 12, 128)  0           conv2d_214[0][0]
#                                                                  add_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 12, 12, 128)  512         add_84[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 12, 12, 128)  0           batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 25, 25, 64)   73792       activation_214[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 25, 25, 128)  0           conv2d_transpose_18[0][0]
#                                                                  activation_199[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 25, 25, 128)  0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 25, 25, 64)   73792       dropout_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 25, 25, 64)   256         conv2d_215[0][0]
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 25, 25, 64)   0           batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 25, 25, 64)   36928       activation_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 25, 25, 64)   256         conv2d_216[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 25, 25, 64)   0           batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 25, 25, 64)   36928       activation_216[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 25, 25, 64)   0           conv2d_217[0][0]
#                                                                  conv2d_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 25, 25, 64)   256         add_85[0][0]
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 25, 25, 64)   0           batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 25, 25, 64)   36928       activation_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 25, 25, 64)   256         conv2d_218[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 25, 25, 64)   0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 25, 25, 64)   36928       activation_218[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 25, 25, 64)   0           conv2d_219[0][0]
#                                                                  add_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 25, 25, 64)   256         add_86[0][0]
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 25, 25, 64)   0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 50, 50, 32)   18464       activation_219[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 50, 50, 64)   0           conv2d_transpose_19[0][0]
#                                                                  activation_194[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 50, 50, 64)   0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 50, 50, 32)   18464       dropout_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 50, 50, 32)   128         conv2d_220[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 50, 50, 32)   0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 50, 50, 32)   9248        activation_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 50, 50, 32)   128         conv2d_221[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 50, 50, 32)   0           batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 50, 50, 32)   9248        activation_221[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 50, 50, 32)   0           conv2d_222[0][0]
#                                                                  conv2d_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 50, 50, 32)   128         add_87[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 50, 50, 32)   0           batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 50, 50, 32)   9248        activation_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 50, 50, 32)   128         conv2d_223[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 50, 50, 32)   0           batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 50, 50, 32)   9248        activation_223[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 50, 50, 32)   0           conv2d_224[0][0]
#                                                                  add_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 50, 50, 32)   128         add_88[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 50, 50, 32)   0           batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 101, 101, 16) 4624        activation_224[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 101, 101, 32) 0           conv2d_transpose_20[0][0]
#                                                                  activation_189[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 101, 101, 32) 0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 101, 101, 16) 4624        dropout_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 101, 101, 16) 64          conv2d_225[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 101, 101, 16) 0           batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 101, 101, 16) 2320        activation_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 101, 101, 16) 64          conv2d_226[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 101, 101, 16) 0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 101, 101, 16) 2320        activation_226[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 101, 101, 16) 0           conv2d_227[0][0]
#                                                                  conv2d_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 101, 101, 16) 64          add_89[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 101, 101, 16) 0           batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 101, 101, 16) 2320        activation_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 101, 101, 16) 64          conv2d_228[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 101, 101, 16) 0           batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 101, 101, 16) 2320        activation_228[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 101, 101, 16) 0           conv2d_229[0][0]
#                                                                  add_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 101, 101, 16) 64          add_90[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 101, 101, 16) 0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 101, 101, 1)  17          activation_229[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 101, 101, 1)  0           conv2d_230[0][0]
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
# IoU score based on cross entropy loss:
for cv_index in range(cv_total):
    print(f"cv {cv_index} ious = {ious[cv_index]}")
# Out:
# cv 0 ious = 0.6992063492063492
# cv 1 ious = 0.6295999999999999
# cv 2 ious = 0.6845528455284552
# cv 3 ious = 0.7008196721311475
# cv 4 ious = 0.7091666666666666

# %% [markdown]
# ### 5.3 Second round of training: $\eta_2=0.0005$ with Lovasz hinge as loss <a id="cell_4_3"></a>

# %% [markdown]
# Second pass of training with $\eta_2=0.0005$. I use 10 epochs here for demonstration purpose. This time, the loss function is swithed from cross entropy to Lovasz loss.

# %%
# training with Lovasz loss
ious1 = [0] * cv_total

epochs = 10  # small number for demonstration
batch_size = 32
learning_rate = 0.0005

for cv_index in range(cv_total):
    basic_name = f'Unet_resnet_{date}_v{version}_cv{cv_index+1}'
    print('############################################\n', basic_name)
    inp_model_name = basic_name + '.model'
    save_model_name = basic_name + 's.model'
    
    # train, valid split
    x_train, y_train, x_valid, y_valid =  get_cv_data(cv_index+1)
    
    # Data augmentation, flip left-right
    x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
    y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
    
    # load model from previous training
    model1 = load_model(inp_model_name,custom_objects={'my_iou_metric': my_iou_metric})
    
    # remove activation layer and use losvasz loss
    input_x = model1.layers[0].input
    output_layer = model1.layers[-1].input
    model = Model(input_x, output_layer)
    c = optimizers.adam(lr = learning_rate)
    
    # lovasz_loss need input range (-∞，+∞), so remove the last "sigmoid" activation  
    # Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
    model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])
    
    # model ckpt, save model with name "save_model_name"
    model_checkpoint = ModelCheckpoint(save_model_name, monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=0)
    
    # early_stopping (not used) for future implementation
    early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=0)
    
    # reduced learning rate (not used) for future implementation
    reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=0)

    #list_callbacks = [model_checkpoint, reduce_lr,early_stopping]  # for future usage
    list_callbacks = [model_checkpoint]
    
    # plot fit history
    history = model.fit(x_train, y_train,
                        validation_data=[x_valid, y_valid], 
                        epochs=epochs,
                        batch_size=batch_size, 
                        callbacks=list_callbacks,
                        shuffle=False,
                        verbose=2)
    plot_history(history,'my_iou_metric_2')
    
    # load model
    model.load_weights(save_model_name)
    # make prediction
    preds_valid = predict_result(model,x_valid,img_size_target)
    # get IoUs for each CV
    ious1[cv_index] = get_iou_vector(y_valid, (preds_valid > 0.5))
# Out:
# ############################################
#  Unet_resnet_0207_v01a_cv1
# Train on 980 samples, validate on 126 samples
# Epoch 1/10
#  - 28s - loss: -1.3071e-01 - my_iou_metric_2: 0.8081 - val_loss: 0.9251 - val_my_iou_metric_2: 0.6571
# Epoch 2/10
#  - 13s - loss: -2.5191e-01 - my_iou_metric_2: 0.8468 - val_loss: 0.8545 - val_my_iou_metric_2: 0.6913
# Epoch 3/10
#  - 13s - loss: -3.3006e-01 - my_iou_metric_2: 0.8666 - val_loss: 0.8974 - val_my_iou_metric_2: 0.6905
# Epoch 4/10
#  - 13s - loss: -3.2532e-01 - my_iou_metric_2: 0.8572 - val_loss: 0.8116 - val_my_iou_metric_2: 0.6754
# Epoch 5/10
#  - 13s - loss: -2.8188e-01 - my_iou_metric_2: 0.8489 - val_loss: 1.6622 - val_my_iou_metric_2: 0.3516
# Epoch 6/10
#  - 13s - loss: -3.7261e-01 - my_iou_metric_2: 0.8741 - val_loss: 0.2726 - val_my_iou_metric_2: 0.7349
# Epoch 7/10
#  - 13s - loss: -3.6762e-01 - my_iou_metric_2: 0.8665 - val_loss: 0.8076 - val_my_iou_metric_2: 0.6714
# Epoch 8/10
#  - 13s - loss: -3.5932e-01 - my_iou_metric_2: 0.8633 - val_loss: 0.7634 - val_my_iou_metric_2: 0.6952
# Epoch 9/10
#  - 13s - loss: -3.7565e-01 - my_iou_metric_2: 0.8669 - val_loss: 0.9613 - val_my_iou_metric_2: 0.6667
# Epoch 10/10
#  - 13s - loss: -4.2255e-01 - my_iou_metric_2: 0.8777 - val_loss: 0.8804 - val_my_iou_metric_2: 0.6548
# ############################################
#  Unet_resnet_0207_v01a_cv2
# Train on 982 samples, validate on 125 samples
# Epoch 1/10
#  - 29s - loss: 0.2799 - my_iou_metric_2: 0.6394 - val_loss: -7.0809e-02 - val_my_iou_metric_2: 0.6888
# Epoch 2/10
#  - 13s - loss: 0.2207 - my_iou_metric_2: 0.6512 - val_loss: 0.7123 - val_my_iou_metric_2: 0.4160
# Epoch 3/10
#  - 13s - loss: 0.1740 - my_iou_metric_2: 0.6677 - val_loss: 1.7094 - val_my_iou_metric_2: 0.0056
# Epoch 4/10
#  - 13s - loss: 0.1442 - my_iou_metric_2: 0.6752 - val_loss: 1.3396 - val_my_iou_metric_2: 0.0064
# Epoch 5/10
#  - 13s - loss: 0.1408 - my_iou_metric_2: 0.6787 - val_loss: 1.9236 - val_my_iou_metric_2: 0.0168
# Epoch 6/10
#  - 13s - loss: 0.1441 - my_iou_metric_2: 0.6775 - val_loss: 0.8120 - val_my_iou_metric_2: 0.6216
# Epoch 7/10
#  - 13s - loss: 0.1277 - my_iou_metric_2: 0.6807 - val_loss: 0.8805 - val_my_iou_metric_2: 0.6824
# Epoch 8/10
#  - 13s - loss: 0.1166 - my_iou_metric_2: 0.6834 - val_loss: 0.9341 - val_my_iou_metric_2: 0.6872
# Epoch 9/10
#  - 13s - loss: 0.1095 - my_iou_metric_2: 0.6872 - val_loss: 0.6025 - val_my_iou_metric_2: 0.6552
# Epoch 10/10
#  - 13s - loss: 0.1328 - my_iou_metric_2: 0.6884 - val_loss: 2.1903 - val_my_iou_metric_2: 0.0000e+00
# ############################################
#  Unet_resnet_0207_v01a_cv3
# Train on 986 samples, validate on 123 samples
# Epoch 1/10
#  - 32s - loss: -2.9822e-02 - my_iou_metric_2: 0.7725 - val_loss: 0.8401 - val_my_iou_metric_2: 0.6862
# Epoch 2/10
#  - 13s - loss: -1.7689e-01 - my_iou_metric_2: 0.8351 - val_loss: 0.8074 - val_my_iou_metric_2: 0.6984
# Epoch 3/10
#  - 13s - loss: -2.0753e-01 - my_iou_metric_2: 0.8246 - val_loss: 0.7990 - val_my_iou_metric_2: 0.6683
# Epoch 4/10
#  - 13s - loss: -2.3438e-01 - my_iou_metric_2: 0.8397 - val_loss: 0.7483 - val_my_iou_metric_2: 0.6886
# Epoch 5/10
#  - 13s - loss: -2.7419e-01 - my_iou_metric_2: 0.8453 - val_loss: 0.6772 - val_my_iou_metric_2: 0.6911
# Epoch 6/10
#  - 13s - loss: -3.1134e-01 - my_iou_metric_2: 0.8582 - val_loss: 0.6308 - val_my_iou_metric_2: 0.7138
# Epoch 7/10
#  - 13s - loss: -3.5547e-01 - my_iou_metric_2: 0.8676 - val_loss: 0.5445 - val_my_iou_metric_2: 0.7122
# Epoch 8/10
#  - 13s - loss: -3.9048e-01 - my_iou_metric_2: 0.8754 - val_loss: 0.7332 - val_my_iou_metric_2: 0.7016
# Epoch 9/10
#  - 13s - loss: -3.6952e-01 - my_iou_metric_2: 0.8737 - val_loss: 0.7201 - val_my_iou_metric_2: 0.7106
# Epoch 10/10
#  - 13s - loss: -4.0096e-01 - my_iou_metric_2: 0.8782 - val_loss: 0.2175 - val_my_iou_metric_2: 0.6854
# ############################################
#  Unet_resnet_0207_v01a_cv4
# Train on 988 samples, validate on 122 samples
# Epoch 1/10
#  - 34s - loss: 0.2829 - my_iou_metric_2: 0.6425 - val_loss: 0.1235 - val_my_iou_metric_2: 0.7648
# Epoch 2/10
#  - 13s - loss: 0.1262 - my_iou_metric_2: 0.7532 - val_loss: 0.0128 - val_my_iou_metric_2: 0.7246
# Epoch 3/10
#  - 13s - loss: 0.0964 - my_iou_metric_2: 0.8071 - val_loss: 0.6804 - val_my_iou_metric_2: 0.6984
# Epoch 4/10
#  - 13s - loss: 0.0226 - my_iou_metric_2: 0.8017 - val_loss: 0.6484 - val_my_iou_metric_2: 0.7000
# Epoch 5/10
#  - 13s - loss: -3.3711e-02 - my_iou_metric_2: 0.8162 - val_loss: 0.5521 - val_my_iou_metric_2: 0.5721
# Epoch 6/10
#  - 13s - loss: -1.2020e-02 - my_iou_metric_2: 0.8127 - val_loss: 0.7040 - val_my_iou_metric_2: 0.7016
# Epoch 7/10
#  - 13s - loss: -6.5977e-02 - my_iou_metric_2: 0.8183 - val_loss: 0.7600 - val_my_iou_metric_2: 0.6787
# Epoch 8/10
#  - 13s - loss: -1.3552e-02 - my_iou_metric_2: 0.7885 - val_loss: 1.6362 - val_my_iou_metric_2: 0.3721
# Epoch 9/10
#  - 13s - loss: -1.2025e-01 - my_iou_metric_2: 0.8296 - val_loss: 0.6485 - val_my_iou_metric_2: 0.6664
# Epoch 10/10
#  - 13s - loss: -1.2463e-01 - my_iou_metric_2: 0.8335 - val_loss: 0.6707 - val_my_iou_metric_2: 0.6795
# ############################################
#  Unet_resnet_0207_v01a_cv5
# Train on 992 samples, validate on 120 samples
# Epoch 1/10
#  - 37s - loss: -1.3898e-01 - my_iou_metric_2: 0.8333 - val_loss: 1.2931 - val_my_iou_metric_2: 0.7092
# Epoch 2/10
#  - 13s - loss: -2.9817e-01 - my_iou_metric_2: 0.8756 - val_loss: 1.0002 - val_my_iou_metric_2: 0.7083
# Epoch 3/10
#  - 13s - loss: -3.1453e-01 - my_iou_metric_2: 0.8726 - val_loss: 0.0099 - val_my_iou_metric_2: 0.8108
# Epoch 4/10
#  - 13s - loss: -3.7714e-01 - my_iou_metric_2: 0.8806 - val_loss: 2.2110 - val_my_iou_metric_2: 0.2842
# Epoch 5/10
#  - 13s - loss: -3.8932e-01 - my_iou_metric_2: 0.8797 - val_loss: 0.4909 - val_my_iou_metric_2: 0.6958
# Epoch 6/10
#  - 13s - loss: -4.0298e-01 - my_iou_metric_2: 0.8823 - val_loss: 1.0095 - val_my_iou_metric_2: 0.7092
# Epoch 7/10
#  - 13s - loss: -3.9456e-01 - my_iou_metric_2: 0.8826 - val_loss: 1.3800 - val_my_iou_metric_2: 0.7075
# Epoch 8/10
#  - 13s - loss: -3.1247e-01 - my_iou_metric_2: 0.8587 - val_loss: 1.8593 - val_my_iou_metric_2: 0.7092
# Epoch 9/10
#  - 13s - loss: -4.1634e-01 - my_iou_metric_2: 0.8848 - val_loss: 1.2228 - val_my_iou_metric_2: 0.6283
# Epoch 10/10
#  - 13s - loss: -4.1219e-01 - my_iou_metric_2: 0.8841 - val_loss: 1.0890 - val_my_iou_metric_2: 0.7075

# %%
# IoU score based on Lovasz loss
for cv_index in range(cv_total):
    print(f"cv {cv_index} ious1 = {ious1[cv_index]}")
# Out:
# cv 0 ious1 = 0.7857142857142857
# cv 1 ious1 = 0.8423999999999998
# cv 2 ious1 = 0.7040650406504064
# cv 3 ious1 = 0.7754098360655737
# cv 4 ious1 = 0.8099999999999999

# %% [markdown]
# ### 5.4 Thrid round of training: $\eta_3=0.0001$ with Lovasz hinge as loss <a id="cell_4_4"></a>

# %% [markdown]
# Third pass of training with $\eta_3=0.0001$. I use 10 epochs here for demonstration purpose. This time, the loss function is swithed from cross entropy to Lovasz loss.

# %%
# 3rd training with Lovasz loss
# Second with fix lr=0.0001, epoch=100
# no early stopping, no reduced_lr
ious3 = [0] * cv_total

epochs = 10  # small number for demonstration
batch_size = 32
learning_rate = 0.0001

for cv_index in range(cv_total):
    # read-in weights from best-trained result (1013_v12_cv?s2.model)
    basic_name1 = f'Unet_resnet_{date}_v{version}_cv{cv_index+1}'
    print('############################################\n', basic_name1)
    inp_model_name = basic_name1 + 's.model'
    basic_name2 = f'Unet_resnet_{date}_v{version}_cv{cv_index+1}'
    print('############################################\n', basic_name2)
    save_model_name = basic_name2 + 's2.model'
    
    # train, valid split
    x_train, y_train, x_valid, y_valid =  get_cv_data(cv_index+1)
    
    # Data augmentation, flip left/right only
    x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
    y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
    
    # load model from previous training
    model = load_model(inp_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2, 
                                                       'lovasz_loss': lovasz_loss})
    # remove layter activation layer and use losvasz loss
    c = optimizers.adam(lr = learning_rate)
    
    # lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
    # Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
    model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])
    
    #early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
    #reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)
    
    model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=0)
        
    # model fit & plot history
    history = model.fit(x_train, y_train,
                        validation_data=[x_valid, y_valid], 
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[model_checkpoint],
                        shuffle=False,
                        verbose=2)
    plot_history(history,'my_iou_metric_2')
    
    # load model
    model.load_weights(save_model_name)
    # make prediction
    preds_valid = predict_result(model,x_valid,img_size_target)
    # get IoU scores
    ious3[cv_index] = get_iou_vector(y_valid, (preds_valid > 0.5))
# Out:
# ############################################
#  Unet_resnet_0207_v01a_cv1
# ############################################
#  Unet_resnet_0207_v01a_cv1
# Train on 980 samples, validate on 126 samples
# Epoch 1/10
#  - 44s - loss: -4.1560e-01 - my_iou_metric_2: 0.8812 - val_loss: -1.3424e-01 - val_my_iou_metric_2: 0.7889
# Epoch 2/10
#  - 13s - loss: -4.4880e-01 - my_iou_metric_2: 0.8927 - val_loss: 0.9273 - val_my_iou_metric_2: 0.4976
# Epoch 3/10
#  - 13s - loss: -4.6294e-01 - my_iou_metric_2: 0.8926 - val_loss: 0.1146 - val_my_iou_metric_2: 0.7611
# Epoch 4/10
#  - 13s - loss: -4.6073e-01 - my_iou_metric_2: 0.8933 - val_loss: 0.4443 - val_my_iou_metric_2: 0.7016
# Epoch 5/10
#  - 13s - loss: -4.6539e-01 - my_iou_metric_2: 0.8915 - val_loss: 0.2737 - val_my_iou_metric_2: 0.7254
# Epoch 6/10
#  - 13s - loss: -4.6989e-01 - my_iou_metric_2: 0.8910 - val_loss: -2.7277e-01 - val_my_iou_metric_2: 0.8421
# Epoch 7/10
#  - 13s - loss: -4.6762e-01 - my_iou_metric_2: 0.8928 - val_loss: -5.5527e-02 - val_my_iou_metric_2: 0.8056
# Epoch 8/10
#  - 13s - loss: -4.7304e-01 - my_iou_metric_2: 0.8950 - val_loss: -2.3587e-01 - val_my_iou_metric_2: 0.8310
# Epoch 9/10
#  - 13s - loss: -4.7982e-01 - my_iou_metric_2: 0.8945 - val_loss: 0.3364 - val_my_iou_metric_2: 0.5738
# Epoch 10/10
#  - 13s - loss: -4.8268e-01 - my_iou_metric_2: 0.8934 - val_loss: -7.9570e-02 - val_my_iou_metric_2: 0.8048
# ############################################
#  Unet_resnet_0207_v01a_cv2
# ############################################
#  Unet_resnet_0207_v01a_cv2
# Train on 982 samples, validate on 125 samples
# Epoch 1/10
#  - 45s - loss: 0.1996 - my_iou_metric_2: 0.6467 - val_loss: -6.9275e-02 - val_my_iou_metric_2: 0.6912
# Epoch 2/10
#  - 13s - loss: 0.1662 - my_iou_metric_2: 0.6645 - val_loss: 0.0339 - val_my_iou_metric_2: 0.6848
# Epoch 3/10
#  - 13s - loss: 0.1504 - my_iou_metric_2: 0.6660 - val_loss: 0.6066 - val_my_iou_metric_2: 0.4576
# Epoch 4/10
#  - 13s - loss: 0.1403 - my_iou_metric_2: 0.6665 - val_loss: 0.8070 - val_my_iou_metric_2: 0.3616
# Epoch 5/10
#  - 13s - loss: 0.1374 - my_iou_metric_2: 0.6665 - val_loss: 0.3630 - val_my_iou_metric_2: 0.5304
# Epoch 6/10
#  - 13s - loss: 0.1310 - my_iou_metric_2: 0.6698 - val_loss: 0.2223 - val_my_iou_metric_2: 0.6072
# Epoch 7/10
#  - 13s - loss: 0.1241 - my_iou_metric_2: 0.6733 - val_loss: 0.3252 - val_my_iou_metric_2: 0.5872
# Epoch 8/10
#  - 13s - loss: 0.1251 - my_iou_metric_2: 0.6779 - val_loss: 0.5095 - val_my_iou_metric_2: 0.5288
# Epoch 9/10
#  - 13s - loss: 0.1071 - my_iou_metric_2: 0.6787 - val_loss: 0.4424 - val_my_iou_metric_2: 0.5536
# Epoch 10/10
#  - 13s - loss: 0.1051 - my_iou_metric_2: 0.6805 - val_loss: 0.3207 - val_my_iou_metric_2: 0.5960
# ############################################
#  Unet_resnet_0207_v01a_cv3
# ############################################
#  Unet_resnet_0207_v01a_cv3
# Train on 986 samples, validate on 123 samples
# Epoch 1/10
#  - 51s - loss: -3.6917e-01 - my_iou_metric_2: 0.8766 - val_loss: 0.6759 - val_my_iou_metric_2: 0.7041
# Epoch 2/10
#  - 13s - loss: -3.9513e-01 - my_iou_metric_2: 0.8749 - val_loss: 0.6833 - val_my_iou_metric_2: 0.7008
# Epoch 3/10
#  - 13s - loss: -3.9833e-01 - my_iou_metric_2: 0.8793 - val_loss: -3.1743e-01 - val_my_iou_metric_2: 0.8650
# Epoch 4/10
#  - 13s - loss: -4.1786e-01 - my_iou_metric_2: 0.8817 - val_loss: 0.0742 - val_my_iou_metric_2: 0.7431
# Epoch 5/10
#  - 13s - loss: -4.1760e-01 - my_iou_metric_2: 0.8828 - val_loss: 0.0320 - val_my_iou_metric_2: 0.7423
# Epoch 6/10
#  - 13s - loss: -4.3645e-01 - my_iou_metric_2: 0.8881 - val_loss: 0.0528 - val_my_iou_metric_2: 0.7374
# Epoch 7/10
#  - 13s - loss: -4.3750e-01 - my_iou_metric_2: 0.8880 - val_loss: -2.1253e-01 - val_my_iou_metric_2: 0.8260
# Epoch 8/10
#  - 13s - loss: -4.2279e-01 - my_iou_metric_2: 0.8853 - val_loss: -2.9346e-01 - val_my_iou_metric_2: 0.8545
# Epoch 9/10
#  - 13s - loss: -4.4721e-01 - my_iou_metric_2: 0.8873 - val_loss: -3.6264e-01 - val_my_iou_metric_2: 0.8797
# Epoch 10/10
#  - 13s - loss: -4.5253e-01 - my_iou_metric_2: 0.8891 - val_loss: -3.5497e-01 - val_my_iou_metric_2: 0.8797
# ############################################
#  Unet_resnet_0207_v01a_cv4
# ############################################
#  Unet_resnet_0207_v01a_cv4
# Train on 988 samples, validate on 122 samples
# Epoch 1/10
#  - 53s - loss: 0.1345 - my_iou_metric_2: 0.7205 - val_loss: -1.8662e-02 - val_my_iou_metric_2: 0.8074
# Epoch 2/10
#  - 13s - loss: 0.0880 - my_iou_metric_2: 0.7728 - val_loss: -4.1959e-02 - val_my_iou_metric_2: 0.8156
# Epoch 3/10
#  - 13s - loss: 0.0633 - my_iou_metric_2: 0.7980 - val_loss: 0.0646 - val_my_iou_metric_2: 0.7828
# Epoch 4/10
#  - 13s - loss: 0.0437 - my_iou_metric_2: 0.8075 - val_loss: -5.5167e-02 - val_my_iou_metric_2: 0.8402
# Epoch 5/10
#  - 13s - loss: 0.0232 - my_iou_metric_2: 0.8219 - val_loss: 0.1315 - val_my_iou_metric_2: 0.7418
# Epoch 6/10
#  - 13s - loss: -7.4899e-03 - my_iou_metric_2: 0.8224 - val_loss: -8.2962e-03 - val_my_iou_metric_2: 0.7975
# Epoch 7/10
#  - 13s - loss: -2.8949e-02 - my_iou_metric_2: 0.8280 - val_loss: -4.4900e-02 - val_my_iou_metric_2: 0.8156
# Epoch 8/10
#  - 13s - loss: -4.7230e-02 - my_iou_metric_2: 0.8388 - val_loss: -1.1757e-01 - val_my_iou_metric_2: 0.8426
# Epoch 9/10
#  - 13s - loss: -5.4887e-02 - my_iou_metric_2: 0.8357 - val_loss: -1.1751e-01 - val_my_iou_metric_2: 0.8131
# Epoch 10/10
#  - 13s - loss: -6.4938e-02 - my_iou_metric_2: 0.8352 - val_loss: 0.5316 - val_my_iou_metric_2: 0.7016
# ############################################
#  Unet_resnet_0207_v01a_cv5
# ############################################
#  Unet_resnet_0207_v01a_cv5
# Train on 992 samples, validate on 120 samples
# Epoch 1/10
#  - 60s - loss: -3.8150e-01 - my_iou_metric_2: 0.8846 - val_loss: 0.3052 - val_my_iou_metric_2: 0.7667
# Epoch 2/10
#  - 14s - loss: -4.0359e-01 - my_iou_metric_2: 0.8890 - val_loss: -3.3850e-01 - val_my_iou_metric_2: 0.8725
# Epoch 3/10
#  - 13s - loss: -4.1469e-01 - my_iou_metric_2: 0.8905 - val_loss: 0.1202 - val_my_iou_metric_2: 0.7908
# Epoch 4/10
#  - 13s - loss: -4.2954e-01 - my_iou_metric_2: 0.8942 - val_loss: -2.0021e-01 - val_my_iou_metric_2: 0.8525
# Epoch 5/10
#  - 13s - loss: -4.3139e-01 - my_iou_metric_2: 0.8932 - val_loss: 0.8500 - val_my_iou_metric_2: 0.7083
# Epoch 6/10
#  - 14s - loss: -4.4465e-01 - my_iou_metric_2: 0.8942 - val_loss: 0.8399 - val_my_iou_metric_2: 0.7092
# Epoch 7/10
#  - 14s - loss: -4.3218e-01 - my_iou_metric_2: 0.8920 - val_loss: 0.7533 - val_my_iou_metric_2: 0.7175
# Epoch 8/10
#  - 14s - loss: -4.6237e-01 - my_iou_metric_2: 0.8976 - val_loss: 0.7546 - val_my_iou_metric_2: 0.7175
# Epoch 9/10
#  - 13s - loss: -4.5115e-01 - my_iou_metric_2: 0.8961 - val_loss: 0.7271 - val_my_iou_metric_2: 0.7175
# Epoch 10/10
#  - 13s - loss: -4.6278e-01 - my_iou_metric_2: 0.8977 - val_loss: 0.8355 - val_my_iou_metric_2: 0.7083

# %%
# calcuate average ious
def sum_list(items):
    sum_numbers = 0
    for x in items:
        sum_numbers += x
    return sum_numbers

# 2nd round training with New loss
for cv_index in range(cv_total):
    print(f"cv {cv_index} ious3 = {ious3[cv_index]}")
    
print(f"cv avg ious3 = ", sum_list(ious3)/len(ious3))
# Out:
# cv 0 ious3 = 0.85
# cv 1 ious3 = 0.8584
# cv 2 ious3 = 0.8715447154471544
# cv 3 ious3 = 0.8434426229508197
# cv 4 ious3 = 0.8833333333333333
# cv avg ious3 =  0.8613441343462614

# %%
"""
used for converting the decoded image to rle mask
Fast compared to previous one
"""
def rle_encode(im):
    '''
    im: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = im.flatten(order = 'F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %% [markdown]
# ## 6. Result <a id='cell_5'></a>

# %% [markdown]
# ### 6.1 Load test seismic images <a id="cell_5_1"></a>

# %% [markdown]
# Test seismic image is from the third inline.

# %%
test_df = pd.read_excel("C:/Users/idrun/Documents/01_DataScience/03_Salt_paper/03_png/test_1113a.xlsx", index_col='id')
x_test = np.array([(np.array(load_img("C:/Users/idrun/Documents/01_DataScience/03_Salt_paper/03_png/tmp_new_1113/images/test/image_{}.png".format(idx), color_mode = "grayscale"))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)
# Out:
# HBox(children=(IntProgress(value=0, max=308), HTML(value='')))

# %% [markdown]
# Let's load final models and make predictions. The final prediction will be the average of all 5 CV models.

# %%
# average the predictions from different folds
t1 = time.time()
preds_test = np.zeros(np.squeeze(x_test).shape)
for cv_index in range(cv_total):
    basic_name = f'Unet_resnet_{date}_v{version}_cv{cv_index+1}'
    print('############################################\n', basic_name)
    model = load_model(basic_name + 's2.model',custom_objects={'my_iou_metric_2': my_iou_metric_2, 
                                                       'lovasz_loss': lovasz_loss})
    model.load_weights(basic_name + 's2.model')
    preds_test += predict_result(model,x_test,img_size_target) /cv_total
t2 = time.time()

print(f"Usedtime = {t2-t1} s")
# Out:
# ############################################
#  Unet_resnet_0207_v01a_cv1
# ############################################
#  Unet_resnet_0207_v01a_cv2
# ############################################
#  Unet_resnet_0207_v01a_cv3
# ############################################
#  Unet_resnet_0207_v01a_cv4
# ############################################
#  Unet_resnet_0207_v01a_cv5
# Usedtime = 870.2645919322968 s

# %% [markdown]
# ### 6.2 Save prediction results as numpy array <a id="cell_5_2"></a>

# %%
# save preds_test as a file
np.save('preds_test_0207.npy', preds_test)  
preds_test.shape
# Out:
# (308, 101, 101)

# %% [markdown]
# ### 6.3 Read back predictions and combine <a id="cell_5_3"></a>

# %%
# Compatability Imports
from __future__ import print_function
from os.path import isfile, join

import segyio
from os import listdir
import numpy as np
import scipy.misc

from skimage.io import imread, imshow
#from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

import pandas as pd

# load in predictions from Yu
preds = np.load('preds_test_0207.npy')  # 
preds.shape
# Out:
# (308, 101, 101)

# %%
# QC one block image from prediction
# fixed scale after cropping
# preds > 0.45 gets value 0 (non-salt, white)
# preds <= 0.45 gets value 1 (salt, black)

preds1 = np.where(preds>0.45, 0, 1)

plt.figure(num=None, figsize=(12,6))
plt.imshow(preds1[683-616], cmap='gray_r', vmin=0, vmax=1)

# %%
# define the function for merging blocks into a full inline
def mergebk(splits):
    mergebk = []

    for i in range(11):
        beg = i * 28
        end = (i+1) * 28
        tmp = splits[beg:end]
        tmp = np.hstack(tmp)
        mergebk.append(tmp)

    mergebk= np.vstack(np.array(mergebk))
    return(mergebk)

# %%
# ground truth of the last inline
labels = np.load('labels.npy')    # labels.npy is from upsampling and have values other than 0, 1
labels_cropped = np.where(labels[-308:] > 0.45, 1, 0)  # use threshold to clip values to 0 & 1 only

# %%
# fixed scale after cropping
# preds > 0.45 gets value 0 (non-salt, white)
# preds <= 0.45 gets value 1 (salt, black)
preds = np.where(preds>0.45, 0, 1)

# %% [markdown]
# ### 6.4 Overlay with block information and compare with true labels <a id="cell_5_4"></a>

# %% [markdown]
# Let's make some plots to QC the salt body prediction against true interpretation. Note the plots here are created using the model with only 40 epochs training. The results will be significantly imporved with more training epochs, more inputs (including additional augmentations including tilting, rotation, scaling etc..).

# %%
# print with block information
plt.rcParams.update({'font.size':16})
fig, ax = plt.subplots(2, 1, figsize = (22, 22))

import matplotlib.ticker as plticker

myInterval=101
loc_x = plticker.MultipleLocator(base=myInterval)
loc_y = plticker.MultipleLocator(base=myInterval)

# "labels_cropped" is true interpretation
# "preds" is prediction from Deep CNN 
for i, data in enumerate([preds, labels_cropped]):    
    offset = 616  # as for the 3rd inline
    ax[i].xaxis.set_major_locator(loc_x)
    ax[i].yaxis.set_major_locator(loc_y)
    ax[i].grid(which='major', axis='both', linestyle='-')
    if (i!=2):
        ax[i].imshow(mergebk(data), cmap='gray_r', vmin=0, vmax=1)
    if (i==2):
        ax[i].imshow(mergebk(data), cmap='gray_r', vmin=-255, vmax=255)

    # Find number of gridsquares in x and y direction
    nx=abs(int(float(ax[i].get_xlim()[1]-ax[i].get_xlim()[0])/float(myInterval)))
    ny=abs(int(float(ax[i].get_ylim()[1]-ax[i].get_ylim()[0])/float(myInterval)))

    # Add some labels to the gridsquares
    #if (i!=2):
    if (i!=3):
        for j in range(ny):
            y=myInterval/2+j*myInterval
            for k in range(nx):
                x=myInterval/2.+float(k)*myInterval
                ax[i].text(x,y,'{:d}'.format(offset + k+j*nx),color='r',ha='center',va='center', fontsize=11)
        
    
    ax[1].set_title("Test line: manual interpretation", fontsize=24)
    ax[0].set_title("Test line: CNN+ResNet prediction (with 40 epochs only)",fontsize=24)

# %% [markdown]
# For comparison, here is the plot shown in my paper after 1000 training epochs ([arXiv:1812.01101](https://arxiv.org/abs/1812.01101)). You can see the salt body prediction accuracy gets improved a lot with more trainings.
#
# ![Paper Plot](./prediction.png)

# %% [markdown]
# ## 7. Discussion <a id='cell_6'></a>

# %% [markdown]
# For the relatively complex CNN architecture we have adopted and given the inputs we already have, we ﬁnd the major improvements are mostly coming from more training epochs. In comparison, though the IoU improvements introduced by using ELU activation function and by using Lov´asz loss function are relatively small (`∼0.002` improvement for each), it is however robust and non-negligible. Ensemble method using stratiﬁed K-fold can further improve the test score by `∼0.015`.
#
# We would expect more training samples, the usage of pre-trained networks (i.e. ResNet34), and the implementation of snapshot ensemble would further improve the prediction accuracy. To speed up the training process and make the models converge faster, strategy of cyclic learning rate could be adopted to further improve. Another possible way to further improve, is by constructing edge detection related features as additional channel for the CNN.
#
# At current stage, the CNN-based salt body interpretation is still not perfect and cannot replace manual interpretation. However, the implementation of deep CNNs on seismic data for salt body identiﬁcation is still promising. For example, the rough salt body derived from CNN can be used as input for Full Waveform Inversion without the need to manually interpret a salt body. Another possible application of this CNN-based method would be the real-time feature segmentation.

# %% [markdown]
# ## 8. Conclusion <a id='cell_7'></a>

# %% [markdown]
# We have implemented a deep CNN-based architecture for automatic seismic data salt body interpretation. The network structure is based on U-net plus ResNet using the Adam algorithm. A few improvements, including ELU activation function, Lovasz cost function, stratiﬁed K-fold cross validation and model averaging, have been made to further improve the salt body prediction accuracy. We have demonstrated that salt body can be successfully delineated using seismic data alone in an automatic manner and the prediction result is conﬁrmed to agree well with a manually interpreted salt body.

# %% [markdown]
# ## Acknowledgements

# %% [markdown]
# We would like to thank SEG Advanced Modeling Corporation for providing SEAM data availabe for public usage, and Dr. Haibin Di for providing the training and the testing datasets used for this R & D.

# %% [markdown]
# ## Appendix <a id="cell_8"></a>

# %% [markdown]
# ### A. Model Summary  <a id="cell_8a"></a>

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 101, 101, 16) 160         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 101, 101, 16) 64          conv2d_185[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 101, 101, 16) 0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 101, 101, 16) 2320        activation_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 101, 101, 16) 64          conv2d_186[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 101, 101, 16) 0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 101, 101, 16) 2320        activation_186[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 101, 101, 16) 0           conv2d_187[0][0]
#                                                                  conv2d_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 101, 101, 16) 64          add_73[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 101, 101, 16) 0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 101, 101, 16) 2320        activation_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 101, 101, 16) 64          conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 101, 101, 16) 0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 101, 101, 16) 2320        activation_188[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 101, 101, 16) 0           conv2d_189[0][0]
#                                                                  add_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 101, 101, 16) 64          add_74[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 101, 101, 16) 0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 50, 50, 16)   0           activation_189[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 50, 50, 16)   0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 50, 50, 32)   4640        dropout_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 50, 50, 32)   128         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 50, 50, 32)   0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 50, 50, 32)   9248        activation_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 50, 50, 32)   128         conv2d_191[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 50, 50, 32)   0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 50, 50, 32)   9248        activation_191[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 50, 50, 32)   0           conv2d_192[0][0]
#                                                                  conv2d_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 50, 50, 32)   128         add_75[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 50, 50, 32)   0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 50, 50, 32)   9248        activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 50, 50, 32)   128         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 50, 50, 32)   0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 50, 50, 32)   9248        activation_193[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 50, 50, 32)   0           conv2d_194[0][0]
#                                                                  add_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 50, 50, 32)   128         add_76[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 50, 50, 32)   0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 25, 25, 32)   0           activation_194[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 25, 25, 32)   0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 25, 25, 64)   18496       dropout_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 25, 25, 64)   256         conv2d_195[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 25, 25, 64)   0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 25, 25, 64)   36928       activation_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 25, 25, 64)   256         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 25, 25, 64)   0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 25, 25, 64)   36928       activation_196[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 25, 25, 64)   0           conv2d_197[0][0]
#                                                                  conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 25, 25, 64)   256         add_77[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 25, 25, 64)   0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 25, 25, 64)   36928       activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 25, 25, 64)   256         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 25, 25, 64)   0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 25, 25, 64)   36928       activation_198[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 25, 25, 64)   0           conv2d_199[0][0]
#                                                                  add_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 25, 25, 64)   256         add_78[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 25, 25, 64)   0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 12, 12, 64)   0           activation_199[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 12, 12, 64)   0           max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 12, 12, 128)  73856       dropout_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 12, 12, 128)  512         conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 12, 12, 128)  0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 12, 12, 128)  147584      activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 12, 12, 128)  512         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 12, 12, 128)  0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 12, 12, 128)  147584      activation_201[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 12, 12, 128)  0           conv2d_202[0][0]
#                                                                  conv2d_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 12, 12, 128)  512         add_79[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 12, 12, 128)  0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 12, 12, 128)  147584      activation_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 12, 12, 128)  512         conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 12, 12, 128)  0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 12, 12, 128)  147584      activation_203[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 12, 12, 128)  0           conv2d_204[0][0]
#                                                                  add_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 12, 12, 128)  512         add_80[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 12, 12, 128)  0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 6, 6, 128)    0           activation_204[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 6, 6, 128)    0           max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 6, 6, 256)    295168      dropout_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 6, 6, 256)    1024        conv2d_205[0][0]
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, 6, 6, 256)    0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 6, 6, 256)    590080      activation_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 6, 6, 256)    1024        conv2d_206[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 6, 6, 256)    0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 6, 6, 256)    590080      activation_206[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 6, 6, 256)    0           conv2d_207[0][0]
#                                                                  conv2d_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 6, 6, 256)    1024        add_81[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 6, 6, 256)    0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 6, 6, 256)    590080      activation_207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 6, 6, 256)    1024        conv2d_208[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 6, 6, 256)    0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 6, 6, 256)    590080      activation_208[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 6, 6, 256)    0           conv2d_209[0][0]
#                                                                  add_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 6, 6, 256)    1024        add_82[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 6, 6, 256)    0           batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 12, 12, 128)  295040      activation_209[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 12, 12, 256)  0           conv2d_transpose_17[0][0]
#                                                                  activation_204[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 12, 12, 256)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 12, 12, 128)  295040      dropout_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 12, 12, 128)  512         conv2d_210[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 12, 12, 128)  0           batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 12, 12, 128)  147584      activation_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 12, 12, 128)  512         conv2d_211[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 12, 12, 128)  0           batch_normalization_207[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 12, 12, 128)  147584      activation_211[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 12, 12, 128)  0           conv2d_212[0][0]
#                                                                  conv2d_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 12, 12, 128)  512         add_83[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 12, 12, 128)  0           batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 12, 12, 128)  147584      activation_212[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 12, 12, 128)  512         conv2d_213[0][0]
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, 12, 12, 128)  0           batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 12, 12, 128)  147584      activation_213[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 12, 12, 128)  0           conv2d_214[0][0]
#                                                                  add_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 12, 12, 128)  512         add_84[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 12, 12, 128)  0           batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 25, 25, 64)   73792       activation_214[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 25, 25, 128)  0           conv2d_transpose_18[0][0]
#                                                                  activation_199[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 25, 25, 128)  0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 25, 25, 64)   73792       dropout_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 25, 25, 64)   256         conv2d_215[0][0]
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 25, 25, 64)   0           batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 25, 25, 64)   36928       activation_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 25, 25, 64)   256         conv2d_216[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 25, 25, 64)   0           batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 25, 25, 64)   36928       activation_216[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 25, 25, 64)   0           conv2d_217[0][0]
#                                                                  conv2d_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 25, 25, 64)   256         add_85[0][0]
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 25, 25, 64)   0           batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 25, 25, 64)   36928       activation_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 25, 25, 64)   256         conv2d_218[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 25, 25, 64)   0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 25, 25, 64)   36928       activation_218[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 25, 25, 64)   0           conv2d_219[0][0]
#                                                                  add_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 25, 25, 64)   256         add_86[0][0]
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 25, 25, 64)   0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 50, 50, 32)   18464       activation_219[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 50, 50, 64)   0           conv2d_transpose_19[0][0]
#                                                                  activation_194[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 50, 50, 64)   0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 50, 50, 32)   18464       dropout_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 50, 50, 32)   128         conv2d_220[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 50, 50, 32)   0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 50, 50, 32)   9248        activation_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 50, 50, 32)   128         conv2d_221[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 50, 50, 32)   0           batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 50, 50, 32)   9248        activation_221[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 50, 50, 32)   0           conv2d_222[0][0]
#                                                                  conv2d_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 50, 50, 32)   128         add_87[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 50, 50, 32)   0           batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 50, 50, 32)   9248        activation_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 50, 50, 32)   128         conv2d_223[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 50, 50, 32)   0           batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 50, 50, 32)   9248        activation_223[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 50, 50, 32)   0           conv2d_224[0][0]
#                                                                  add_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 50, 50, 32)   128         add_88[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 50, 50, 32)   0           batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 101, 101, 16) 4624        activation_224[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 101, 101, 32) 0           conv2d_transpose_20[0][0]
#                                                                  activation_189[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 101, 101, 32) 0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 101, 101, 16) 4624        dropout_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 101, 101, 16) 64          conv2d_225[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 101, 101, 16) 0           batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 101, 101, 16) 2320        activation_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 101, 101, 16) 64          conv2d_226[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 101, 101, 16) 0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 101, 101, 16) 2320        activation_226[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 101, 101, 16) 0           conv2d_227[0][0]
#                                                                  conv2d_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 101, 101, 16) 64          add_89[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 101, 101, 16) 0           batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 101, 101, 16) 2320        activation_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 101, 101, 16) 64          conv2d_228[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 101, 101, 16) 0           batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 101, 101, 16) 2320        activation_228[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 101, 101, 16) 0           conv2d_229[0][0]
#                                                                  add_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 101, 101, 16) 64          add_90[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 101, 101, 16) 0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 101, 101, 1)  17          activation_229[0][0]
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %% [markdown]
# ### B. ReLU vs. ELU comparison <a id="cell_8b"></a>

# %% [markdown]
# Let's plot ReLU activation function

# %%
plt.rcParams.update({'font.size':14})

# ========== Generate ReLU function plot  =====================
import pylab
x = np.linspace(-5,5,1000)  # 100 linearly spaced numbers
y = np.linspace(-5,5,1000)

alpha=1
for i in range(len(x)):
    if (x[i]<0):
        y[i] = 0
    else:
        y[i] = x[i]
    #print("i= {}, {}".format(x[i],y[i]))
    
# compose plot
pylab.plot(x,y, linewidth=5.0, label='ReLU')
plt.ylim(-2, 5)
plt.xlim(-5, 5)
plt.axhline(y=0, color='k',linestyle='-',linewidth=1.0)
plt.axhline(y=-1, color='w', linestyle='--')
plt.axvline(x=0, color='k', linestyle='-',linewidth=1.0)
plt.title(r"ReLU activation function", fontsize=16)
plt.legend()

# %% [markdown]
# Next, let's plot ELU activation function for comparison:

# %%
# ========== Generate ELU function plot  =====================
import pylab
x = np.linspace(-5,5,1000)  # 100 linearly spaced numbers
y = np.linspace(-5,5,1000)

alpha=1
for i in range(len(x)):
    if (x[i]<0):
        y[i] = alpha * (np.exp(x[i]) - 1)
    else:
        y[i] = x[i]
    #print("i= {}, {}".format(x[i],y[i]))
    
# compose plot
pylab.plot(x,y, linewidth=5.0, label='ELU')
plt.ylim(-2, 5)
plt.xlim(-5, 5)
plt.axhline(y=0, color='k',linestyle='-',linewidth=1.0)
plt.axhline(y=-1, color='r', linestyle='--')
plt.axvline(x=0, color='k', linestyle='-',linewidth=1.0)
plt.title(r"ELU activation function ($\alpha$ = 1)", fontsize=16)
plt.legend()

# %% [markdown]
# Comparing with the ReLU function, the ELU activation function has the following characteristics:
# * For x< 0, the ELU has non-zero gradient and thus fix the issue of dying nodes observed in the ReLU function
# * ELU is smooth everywhere even at x=0. This may help to speed up the *Gradient Descent* calculation
# * Due to its exponential nature, the ELU function is generally slower in computation than the ReLU function and its variants

# %% [markdown]
# ## Reference

# %% [markdown]
# Jones, I. and I. Davison, 2014, Seismic Imaging In and Around Salt Bodies. Interpretation, Vol. 2, No. 4.
#
# Maniar, H., S. Ryali, M. S. Kulkarni, and A. Abubakar, 2018, Machine Learning Methods in Geoscience. SEG International Exposition and 88th Annual Meeting, page 4638-4642.
#
# Chen, J. and Y. Zeng, 2018, Application of Machine Learning in Rock Facies Classiﬁcation with Physics-Motivated Feature Augmentation, [arXiv:1808.09856](https://arxiv.org/pdf/1808.09856.pdf)
#
# Di,H.,Z.Wang,andG.AlRegib,2018,WhyusingCNNforSeismicInterpretation? AnInvestigation. SEG International Exposition and 88th Annual Meeting, page 2216-2220.
#
# Abriel, W., 2009, Overview of SEAM Initiative, SEAM workshop presentations: Presented at the 79th Annual International Meeting, SEG.
#
# Ronneberger, O., P. Fischer, and T. Brox, 2015, U-Net: Convolutional Networks for Biomedical Image Segmentation, [arXiv:1505.04597](https://arxiv.org/pdf/1505.04597.pdf)
#
# He, K., X. Zhang, S. Ren, and J. Sun, 2015, Deep Residual Learning for Image Recognition, [arXiv:1512.03385](https://arxiv.org/pdf/1512.03385.pdf)
#
# He, K., X. Zhang, S. Ren, and J. Sun, 2015, Delving Deep into Rectiﬁers: Surpassing Human-Level Performance on ImageNet Classiﬁcation, [arXiv:1502.01852](https://arxiv.org/pdf/1502.01852.pdf)
#
# Clevert, D., T. Unterthiner, and S. Hochreiter, 2015, Fast and Accurate Deep Network Learning by Exponential Linear Units (ELUs), [arXiv:1511.07289](https://arxiv.org/pdf/1511.07289.pdf)
#
# Berman, Maxim and Rannen Triki, Amal and Blaschko, Matthew B., 2018, The Lov´asz-Softmax Loss: A Tractable Surrogate for the Optimization of the Intersection-Over-Union Measure in Neural Networks. The IEEE Conference on Computer Vision and Pattern Recognition (CVPR).
#
# Goodfellow, I., Bengio,Y., and Courville,A., 2016, Deep Learning. MIT Press
#
# Waldeland, A. U., A. C. Jensen, L-J. Gelius, and A. H. S. Solberg, 2018, Convolutional Neural Networks for Automated Seismic Interpretation. The Leading Edge, page 529-537.
#
# Yu, J. and M. B. Blaschko. Learning submodular losses with the Lov´asz hinge. In Proceedings of the 32nd International Conference on Machine Learning, volume 37 of Journal of Machine Learning Research: W&CP , pages 1623-1631, Lille, France, 2015.
#
# Rakhlin,A.,A.Davydow,andS.Nikolenko,2016,LandCoverClassiﬁcationFromSatelliteImagery With U-Net and Lov´asz-Softmax Loss. The IEEE Conference on Computer Vision and Pattern Recognition (CVPR)
# Workshops.
#
# GitHub, https://github.com/bermanmaxim/LovaszSoftmax
#
# Kaggle, https://www.kaggle.com/c/tgs-salt-identification-challenge
